# %%
exps = {
    "SubTB_CFG":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_CFG_subTB_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_subTB/eval/runs/2026-01-04_12-35-04/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_subTB/eval/runs/2026-01-04_12-35-04/test_samples/samples_test_0.csv"
        },
    "TB_CFG":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_CFG_TB_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_TB/eval/runs/2026-01-03_10-54-12/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_TB/eval/runs/2026-01-03_10-54-12/test_samples/samples_test_0.csv"
        },
    "RapTB_mix":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_RapTB_v2_kmin_5_to_2_mix_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_5_to_2_mix/eval/runs/2026-01-03_10-54-12/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_5_to_2_mix/eval/runs/2026-01-03_10-54-12/test_samples/samples_test_0.csv"
        },
    "TB_CFG_Length_SubM":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_CFG_TB_subM_replay_len_func_only_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_TB_subM_replay_len_func_only/eval/runs/2026-01-07_09-13-17/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_TB_subM_replay_len_func_only/eval/runs/2026-01-07_09-13-17/test_samples/samples_test_0.csv"
        },
    "RapTB_Length_SubM":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_len_func_only_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_len_func_only/eval/runs/2026-01-07_09-06-19/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_len_func_only/eval/runs/2026-01-07_09-06-19/test_samples/samples_test_0.csv"
        },
    "TB_CFG_SubM":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_CFG_TB_subM_replay_add_len_func_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_TB_subM_replay_add_len_func/eval/runs/2026-01-07_09-32-57/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_TB_subM_replay_add_len_func/eval/runs/2026-01-07_09-32-57/test_samples/samples_test_0.csv"
        },
    "RapTB_SubM_wo_Length":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay/eval/runs/2026-01-03_11-03-37/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay/eval/runs/2026-01-03_11-03-37/test_samples/samples_test_0.csv",
        },
    "RapTB_SubM":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_add_len_func_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_add_len_func/eval/runs/2026-01-07_09-28-08/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_add_len_func/eval/runs/2026-01-07_09-28-08/test_samples/samples_test_0.csv"
        },
    
}

# %%
exps = {
    "TB_CFG_len15":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_CFG_TB_len_15_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_TB_len_15/eval/runs/2026-01-08_09-40-38/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_CFG_TB_len_15/eval/runs/2026-01-08_09-40-38/test_samples/samples_test_0.csv"
        },
    "RapTB_len15":
        {
            "json": "/data1/xw3763/project/gflow/ChemGFN/evaluation/test_metrics_smiles_RapTB_v2_kmin_10_to_2_mix_len_15_eval_epoch_0_step_0.json",
            "prefix": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_10_to_2_mix_len_15/eval/runs/2026-01-08_09-44-45/prefix_tables/prefix_pos_test_k_correct_0.csv",
            "samples": "/data1/xw3763/project/gflow/ChemGFN/logs/eval/smiles_RapTB_v2_kmin_10_to_2_mix_len_15/eval/runs/2026-01-08_09-44-45/test_samples/samples_test_0.csv"
        },
    
}

# %%
# ============================================================
# ICML-style analysis toolkit (JSON + prefix CSV + samples CSV)
# Directly compatible with your file formats:
#   - samples CSV: columns like "Sampled sentence", "token_ids", "is_valid"
#   - prefix CSV: columns like epoch,k,top1,top5,entropy,eff,n,unique
#   - eval JSON: keys like score_mean_by_len_valid, diversity_by_len_valid, score_count_by_len_valid
# ============================================================

import json
import ast
from dataclasses import dataclass
from typing import Dict, Any, Optional, List, Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try:
    from IPython.display import display
except Exception:
    display = print


# =========================
# Style / Config (edit here)
# =========================
@dataclass
class PlotStyle:
    dpi: int = 170

    figsize_prefix: Tuple[int, int] = (12, 7)
    figsize_nk: Tuple[int, int] = (8, 3)
    figsize_len_hist_bins: Tuple[int, int] = (8, 3)   # binned
    figsize_len_hist_fine: Tuple[int, int] = (8, 3)   # per-length
    figsize_by_len: Tuple[int, int] = (8, 3)

    marker: str = "o"
    linewidth: float = 2.2
    grid_alpha: float = 0.3

    legend_ncol: int = 3
    legend_frameon: bool = True

    suptitle_fontsize: int = 12
    title_fontsize: int = 11
    label_fontsize: int = 10


@dataclass
class Buckets:
    # prefix-length buckets (k)
    prefix_bins: Dict[str, Tuple[int, int]] = None
    # length histogram buckets in JSON keys
    len_bin_labels: List[str] = None

    def __post_init__(self):
        if self.prefix_bins is None:
            self.prefix_bins = {"short": (1, 3), "mid": (4, 7), "long": (8, 10)}
        if self.len_bin_labels is None:
            self.len_bin_labels = ["0-2", "3-5", "6-8", "9-10", "11+"]


@dataclass
class JsonKeys:
    # by-length keys in your eval JSON
    score_mean_by_len_valid: str = "score_mean_by_len_valid"     # (SMILES: QED-by-length) (Expr24: score-by-length)
    diversity_by_len_valid: str = "diversity_by_len_valid"       # token-diversity-by-length (valid-only)
    score_count_by_len_valid: str = "score_count_by_len_valid"   # valid-only count-by-length (fine length histogram)

    # binned fractions (these are typical in your SMILES JSONs; may be absent in Expr24)
    len_valid_frac_prefix: str = "len_valid_frac"                # expects keys like len_valid_frac[0-2]


@dataclass
class SamplesConfig:
    # Your samples CSV (direct compatibility)
    text_cols: Tuple[str, ...] = (
        "Sampled sentence",  # your current file
        "smiles", "SMILES", "sample", "text", "generated", "gen_smiles",
        "sentence", "output", "completion"
    )
    token_ids_cols: Tuple[str, ...] = ("token_ids", "tokens", "token_id_list")
    length_cols: Tuple[str, ...] = ("len_tok", "len", "length", "tok_len", "n_tokens", "num_tokens", "token_len")
    valid_cols: Tuple[str, ...] = ("is_valid", "correct", "valid", "rdkit_valid", "can_parse", "success")

    # cleaning: strip everything after "<|" (handles <|end_of_text|> spam)
    strip_after_special_token: bool = True

    # FPdiv-by-length settings (if RDKit available and strings look like SMILES)
    morgan_radius: int = 2
    morgan_nbits: int = 2048
    max_per_len: int = 512  # cap per length to control O(n^2) pairwise

    # if your CSV uses different names, override here:
    text_col_override: Optional[str] = None
    token_ids_col_override: Optional[str] = None
    length_col_override: Optional[str] = None
    valid_col_override: Optional[str] = None


# =========================
# IO helpers
# =========================
def load_json(path: str) -> Dict[str, Any]:
    with open(path, "r") as f:
        return json.load(f)


def load_prefix_csv(path: str) -> pd.DataFrame:
    df = pd.read_csv(path).copy()
    if "k" not in df.columns or "n" not in df.columns:
        raise ValueError(f"Prefix CSV missing required columns k,n. Found: {list(df.columns)}")

    df["k"] = df["k"].astype(int)
    df = df.sort_values("k").reset_index(drop=True)

    base = float(df.iloc[0]["n"]) if len(df) else np.nan
    df["survival"] = df["n"] / base if (base and base > 0) else np.nan

    if "unique" in df.columns:
        df["unique_rate"] = df["unique"] / df["n"].replace(0, np.nan)
    return df


def load_samples_csv(path: str) -> pd.DataFrame:
    return pd.read_csv(path)


def _infer_col(df: pd.DataFrame, candidates: Tuple[str, ...]) -> Optional[str]:
    for c in candidates:
        if c in df.columns:
            return c
    return None


def _to_bool_series(s: pd.Series) -> pd.Series:
    if s.dtype == bool:
        return s
    return s.astype(str).str.lower().isin(["1", "true", "t", "yes", "y"])


def _clean_text(s: str, strip_after_special_token: bool = True) -> str:
    s = "" if s is None else str(s)
    if strip_after_special_token and "<|" in s:
        s = s.split("<|", 1)[0]
    return s.strip()


def _parse_token_list(x) -> Optional[List[int]]:
    if isinstance(x, list):
        return x
    if not isinstance(x, str):
        return None
    try:
        v = ast.literal_eval(x)
        if isinstance(v, list):
            return v
        return None
    except Exception:
        return None


# =========================
# JSON extraction & tables
# =========================
def extract_by_len_series(j: Dict[str, Any], key: str) -> Optional[pd.Series]:
    if key not in j or j[key] is None or not isinstance(j[key], dict):
        return None
    items = []
    for k, v in j[key].items():
        try:
            items.append((int(k), float(v)))
        except Exception:
            continue
    if not items:
        return None
    items.sort(key=lambda x: x[0])
    return pd.Series({k: v for k, v in items}).sort_index()


def extract_main_metrics(j: Dict[str, Any], buckets: Buckets) -> Dict[str, Any]:
    out = {}

    # robust: your JSON sometimes uses nested names; keep core ones here
    out["acc"] = j.get("acc", j.get("test/validator/acc"))
    out["diversity_valid"] = j.get("diversity_valid", j.get("test/diversity_valid"))
    out["diversity"] = j.get("test/diversity", j.get("diversity"))
    out["score_mean_valid"] = j.get("test/score_mean_valid", j.get("score_mean_valid", None))
    out["score_mean"] = j.get("test/score_mean", j.get("score_mean", None))

    out["len_mean"] = j.get("len_mean", None)
    out["len_std"] = j.get("len_std", None)
    out["len_p50"] = j.get("len_p50", None)
    out["len_p90"] = j.get("len_p90", None)
    out["len_p95"] = j.get("len_p95", None)

    # binned fractions if present (SMILES json usually has these; Expr24 may not)
    for b in buckets.len_bin_labels:
        out[f"len_valid_frac[{b}]"] = j.get(f"len_valid_frac[{b}]", None)
        out[f"len_frac[{b}]"] = j.get(f"len_frac[{b}]", None)

    return out


import numpy as np
import pandas as pd
from typing import Dict, Any, Optional, List

def _get_first(j: Dict[str, Any], keys: List[str], default=None):
    for k in keys:
        if k in j and j[k] is not None:
            return j[k]
    return default

def make_main_table(exps: Dict[str, Dict[str, str]], buckets: Buckets) -> pd.DataFrame:
    rows = []

    for exp_name, payload in exps.items():
        jpath = payload.get("json")
        if not jpath:
            continue
        j = load_json(jpath)

        row: Dict[str, Any] = {"experiment": exp_name}

        # ---- core metrics ----
        row["acc"] = float(_get_first(j, ["test/validator/acc", "acc"], default=np.nan))

        # diversity: your json often contains both test/* and plain keys
        row["diversity_valid"] = float(_get_first(
            j, ["test/diversity_valid", "diversity_valid"], default=np.nan
        ))
        row["diversity"] = float(_get_first(
            j, ["test/diversity", "diversity"], default=np.nan
        ))

        # score/QED: map to your validator keys (qed_filter is usually valid-only)
        row["score_mean_valid"] = float(_get_first(
            j, ["test/validator/qed_filter", "test/qed_filter", "test/validator/qed", "test/qed"],
            default=np.nan
        ))
        row["score_mean"] = float(_get_first(
            j, ["test/validator/qed", "test/qed"],
            default=np.nan
        ))

        # ---- length summary (valid-only) ----
        row["len_mean"] = float(_get_first(
            j, ["test/validator/len_tok_valid_mean", "test/validator/len_tok_mean"], default=np.nan
        ))
        row["len_std"] = float(_get_first(
            j, ["test/validator/len_tok_valid_std", "test/validator/len_tok_std"], default=np.nan
        ))
        row["len_p50"] = float(_get_first(
            j, ["test/validator/len_tok_valid_p50", "test/validator/len_tok_p50"], default=np.nan
        ))
        row["len_p90"] = float(_get_first(
            j, ["test/validator/len_tok_valid_p90", "test/validator/len_tok_p90"], default=np.nan
        ))
        row["len_p95"] = float(_get_first(
            j, ["test/validator/len_tok_valid_p95", "test/validator/len_tok_p95"], default=np.nan
        ))

        # ---- length bin fractions (compute robustly via extract_len_bin_fracs you fixed) ----
        # valid-only binned
        v_fracs = extract_len_bin_fracs(j, buckets.len_bin_labels, valid_only=True)
        a_fracs = extract_len_bin_fracs(j, buckets.len_bin_labels, valid_only=False)

        if v_fracs is not None:
            for b, val in zip(buckets.len_bin_labels, v_fracs):
                row[f"len_valid_frac[{b}]"] = float(val) if val is not None else np.nan
        else:
            for b in buckets.len_bin_labels:
                row[f"len_valid_frac[{b}]"] = np.nan

        if a_fracs is not None:
            for b, val in zip(buckets.len_bin_labels, a_fracs):
                row[f"len_frac[{b}]"] = float(val) if val is not None else np.nan
        else:
            for b in buckets.len_bin_labels:
                row[f"len_frac[{b}]"] = np.nan

        rows.append(row)

    if not rows:
        return pd.DataFrame()

    df = pd.DataFrame(rows).set_index("experiment").sort_index()
    return df


# =========================
# Plots: JSON length histograms (FIXED for your JSON structure)
# =========================
import re
from typing import Dict, Any, Optional, List
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def _parse_len_bin_label(label: str) -> tuple[int, int]:
    """
    Supports:
      "0-2"  -> (0,2)
      "3-5"  -> (3,5)
      "11+"  -> (11,-1)  # -1 means open-ended
      "11- -1" (rare) -> (11,-1)
    """
    s = label.strip()
    if s.endswith("+"):
        lo = int(s[:-1])
        return lo, -1
    m = re.match(r"^\s*(\d+)\s*-\s*(-?\d+)\s*$", s)
    if not m:
        raise ValueError(f"Unrecognized bin label: {label}")
    lo = int(m.group(1))
    hi = int(m.group(2))
    return lo, hi


def _get_counts_dict(j: Dict[str, Any], valid_only: bool) -> Optional[Dict[int, float]]:
    """
    Prefer len_counts(_valid). Fallback to score_count_by_len(_valid).
    Returns dict[int] -> count.
    """
    candidates = []
    if valid_only:
        candidates = ["len_counts_valid", "score_count_by_len_valid"]
    else:
        candidates = ["len_counts", "score_count_by_len"]

    for k in candidates:
        v = j.get(k, None)
        if isinstance(v, dict) and len(v) > 0:
            out = {}
            for kk, vv in v.items():
                try:
                    out[int(kk)] = float(vv)
                except Exception:
                    pass
            if out:
                return out
    return None


def extract_len_bin_fracs(
    j: Dict[str, Any],
    bins: List[str],
    valid_only: bool = True,
) -> Optional[List[float]]:
    """
    Returns a list of bin fractions aligned with `bins`.

    Priority:
      1) Compute from len_counts(_valid) (most robust).
      2) Fallback to reading test/validator/len_tok(_valid)_{lo}_{hi}_frac.
      3) Legacy fallback: len_valid_frac[...] / len_frac[...] (if you ever have them).
    """
    # (1) Compute from counts dict
    counts = _get_counts_dict(j, valid_only=valid_only)
    if counts is not None:
        total = float(sum(counts.values()))
        if total <= 0:
            return None

        out = []
        for b in bins:
            lo, hi = _parse_len_bin_label(b)
            if hi == -1:
                c = sum(v for L, v in counts.items() if L >= lo)
            else:
                c = sum(v for L, v in counts.items() if lo <= L <= hi)
            out.append(float(c / total))
        return out

    # (2) Fallback to validator frac keys (your SMILES JSON has these)
    # Example keys:
    #   test/validator/len_tok_valid_0_2_frac
    #   test/validator/len_tok_0_2_frac
    prefix = "test/validator/len_tok_valid" if valid_only else "test/validator/len_tok"
    vals, found_any = [], False
    for b in bins:
        lo, hi = _parse_len_bin_label(b)
        key_hi = hi
        if hi == -1:
            # your json uses 11_-1 for open ended
            key_hi = -1
        k = f"{prefix}_{lo}_{key_hi}_frac"
        if k in j and j[k] is not None:
            vals.append(float(j[k]))
            found_any = True
        else:
            vals.append(np.nan)
    if found_any:
        return vals

    # (3) Legacy fallback (your previous assumption)
    legacy_prefix = "len_valid_frac" if valid_only else "len_frac"
    vals, found_any = [], False
    for b in bins:
        k = f"{legacy_prefix}[{b}]"
        if k in j and j[k] is not None:
            vals.append(float(j[k]))
            found_any = True
        else:
            vals.append(np.nan)
    return vals if found_any else None


def plot_length_histogram_binned(
    exps: Dict[str, Dict[str, str]],
    buckets,
    style,
    valid_only: bool = True,
    title: str = "Length histogram (valid-only, binned)",
) -> None:
    names, fracs = [], []
    for exp_name, payload in exps.items():
        jpath = payload.get("json")
        if not jpath:
            continue
        j = load_json(jpath)
        v = extract_len_bin_fracs(j, buckets.len_bin_labels, valid_only=valid_only)
        if v is None:
            continue
        names.append(exp_name)
        fracs.append(v)

    if not fracs:
        print("No usable length bins found (counts/validator fracs/legacy fracs).")
        return

    fracs = np.asarray(fracs, dtype=float)
    E, B = fracs.shape
    x = np.arange(B)
    width = 0.8 / max(E, 1)

    plt.figure(figsize=style.figsize_len_hist_bins, dpi=style.dpi)
    for i, exp_name in enumerate(names):
        plt.bar(x + i * width - (E - 1) * width / 2, fracs[i], width=width, label=exp_name)

    plt.xticks(x, buckets.len_bin_labels)
    plt.ylabel("Fraction", fontsize=style.label_fontsize)
    plt.title(title, fontsize=style.title_fontsize)
    plt.grid(True, axis="y", alpha=style.grid_alpha)
    plt.legend(ncol=min(style.legend_ncol, len(names)), frameon=style.legend_frameon)
    plt.tight_layout()
    plt.show()


def plot_length_histogram_fine(
    exps: Dict[str, Dict[str, str]],
    style,
    normalize: bool = True,
    valid_only: bool = True,
    title: str = "Length histogram (valid-only, per-length)",
) -> None:
    """
    FIX: use len_counts(_valid) if present; fallback to score_count_by_len(_valid).
    """
    series_map = {}
    for exp_name, payload in exps.items():
        jpath = payload.get("json")
        if not jpath:
            continue
        j = load_json(jpath)

        counts = _get_counts_dict(j, valid_only=valid_only)
        if counts is None:
            continue

        s = pd.Series(counts).sort_index()
        if normalize:
            denom = float(s.sum())
            s = s / denom if denom > 0 else s * np.nan
        series_map[exp_name] = s

    if not series_map:
        print("No usable per-length counts found (len_counts/score_count_by_len).")
        return

    all_lens = sorted(set().union(*[set(s.index.tolist()) for s in series_map.values()]))
    x = np.array(all_lens, dtype=int)

    plt.figure(figsize=style.figsize_len_hist_fine, dpi=style.dpi)
    for name, s in series_map.items():
        y = np.array([s.get(L, 0.0) for L in all_lens], dtype=float)
        plt.plot(x, y, marker=style.marker, linewidth=style.linewidth, label=name)

    plt.title(title, fontsize=style.title_fontsize)
    plt.xlabel("Length (tokens)", fontsize=style.label_fontsize)
    plt.ylabel("Fraction" if normalize else "Count", fontsize=style.label_fontsize)
    plt.grid(True, alpha=style.grid_alpha)
    plt.legend(ncol=min(style.legend_ncol, len(series_map)), frameon=style.legend_frameon)
    plt.tight_layout()
    plt.show()


def plot_metric_by_length_from_json(
    exps: Dict[str, Dict[str, str]],
    style,
    key: str,
    title: str,
    ylabel: str,
) -> None:
    """
    This part is OK for your JSON: score_mean_by_len_valid and diversity_by_len_valid
    are dict[str length]->value, so extract_by_len_series works.
    """
    series_map = {}
    for exp_name, payload in exps.items():
        jpath = payload.get("json")
        if not jpath:
            continue
        j = load_json(jpath)
        s = extract_by_len_series(j, key)
        if s is None:
            continue
        series_map[exp_name] = s

    if not series_map:
        print(f"No key '{key}' found as dict in any json; skipping '{title}'.")
        return

    all_lens = sorted(set().union(*[set(s.index.tolist()) for s in series_map.values()]))
    x = np.array(all_lens, dtype=int)

    plt.figure(figsize=style.figsize_by_len, dpi=style.dpi)
    for name, s in series_map.items():
        y = np.array([s.get(L, np.nan) for L in all_lens], dtype=float)
        plt.plot(x, y, marker=style.marker, linewidth=style.linewidth, label=name)

    plt.title(title, fontsize=style.title_fontsize)
    plt.xlabel("Length (tokens)", fontsize=style.label_fontsize)
    plt.ylabel(ylabel, fontsize=style.label_fontsize)
    plt.grid(True, alpha=style.grid_alpha)
    plt.legend(ncol=min(style.legend_ncol, len(series_map)), frameon=style.legend_frameon)
    plt.tight_layout()
    plt.show()


# =========================
# Prefix plots + bucket table
# =========================
def add_bin_shading(ax, prefix_bins: Dict[str, Tuple[int, int]]):
    for _, (lo, hi) in prefix_bins.items():
        ax.axvspan(lo, hi, alpha=0.08)


def plot_prefix_panels(exps: Dict[str, Dict[str, str]],
                       buckets: Buckets,
                       style: PlotStyle,
                       suptitle: str = "Prefix metrics (correct-only)") -> None:
    pref = {}
    for exp_name, payload in exps.items():
        ppath = payload.get("prefix")
        if not ppath:
            continue
        pref[exp_name] = load_prefix_csv(ppath)

    if not pref:
        print("No prefix csv provided; skipping prefix plots.")
        return

    fig, axes = plt.subplots(2, 3, figsize=style.figsize_prefix, dpi=style.dpi)

    def plot_curve(ax, ycol, title, ylabel, ylim=None):
        for name, df in pref.items():
            if ycol not in df.columns:
                continue
            ax.plot(df["k"], df[ycol], marker=style.marker, linewidth=style.linewidth, label=name)
        ax.set_title(title, fontsize=style.title_fontsize)
        ax.set_xlabel("k (prefix length)", fontsize=style.label_fontsize)
        ax.set_ylabel(ylabel, fontsize=style.label_fontsize)
        if ylim is not None:
            ax.set_ylim(*ylim)
        ax.grid(True, alpha=style.grid_alpha)
        add_bin_shading(ax, buckets.prefix_bins)

    plot_curve(axes[0, 0], "survival", "Prefix survival (correct-only)", "n(k) / n(1)", ylim=(0, 1.05))
    plot_curve(axes[0, 1], "entropy", "Token entropy vs k (correct-only)", "entropy")
    plot_curve(axes[0, 2], "eff", "Effective support size vs k (correct-only)", "eff")
    plot_curve(axes[1, 0], "top1", "Top-1 mass vs k (collapse ↑)", "top1", ylim=(0, 1.0))
    plot_curve(axes[1, 1], "unique", "Unique tokens vs k (correct-only)", "unique")
    plot_curve(axes[1, 2], "unique_rate", "Unique rate vs k (unique / n)", "unique / n")

    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc="upper center",
               ncol=min(style.legend_ncol, len(labels)), frameon=style.legend_frameon)
    fig.suptitle(suptitle, y=0.98, fontsize=style.suptitle_fontsize)
    fig.tight_layout(rect=[0, 0, 1, 0.93])
    plt.show()

    # n(k)
    plt.figure(figsize=style.figsize_nk, dpi=style.dpi)
    for name, df in pref.items():
        plt.plot(df["k"], df["n"], marker=style.marker, linewidth=style.linewidth, label=name)
    for _, (lo, hi) in buckets.prefix_bins.items():
        plt.axvspan(lo, hi, alpha=0.08)
    plt.title("Reachable correct samples count n(k) vs k (correct-only)", fontsize=style.title_fontsize)
    plt.xlabel("k", fontsize=style.label_fontsize)
    plt.ylabel("n(k)", fontsize=style.label_fontsize)
    plt.grid(True, alpha=style.grid_alpha)
    plt.legend(ncol=min(style.legend_ncol, len(pref)), frameon=style.legend_frameon)
    plt.tight_layout()
    plt.show()


def make_prefix_bucket_table(exps: Dict[str, Dict[str, str]],
                             buckets: Buckets) -> pd.DataFrame:
    AGG_COLS = ["survival", "entropy", "eff", "top1", "unique", "unique_rate", "n"]

    def agg_over_bin(df: pd.DataFrame, lo: int, hi: int) -> Dict[str, float]:
        g = df[(df["k"] >= lo) & (df["k"] <= hi)]
        if len(g) == 0:
            out = {c: np.nan for c in AGG_COLS}
            out["survival_end"] = np.nan
            out["n_end"] = np.nan
            return out
        out = {}
        for c in AGG_COLS:
            out[c] = float(g[c].mean()) if c in g.columns else np.nan
        out["survival_end"] = float(df[df["k"] == hi]["survival"].iloc[0]) if (df["k"] == hi).any() else np.nan
        out["n_end"] = float(df[df["k"] == hi]["n"].iloc[0]) if (df["k"] == hi).any() else np.nan
        return out

    rows = []
    for exp_name, payload in exps.items():
        ppath = payload.get("prefix")
        if not ppath:
            continue
        df = load_prefix_csv(ppath)
        for bucket_name, (lo, hi) in buckets.prefix_bins.items():
            r = {"experiment": exp_name, "bucket": bucket_name, "k_lo": lo, "k_hi": hi}
            r.update(agg_over_bin(df, lo, hi))
            rows.append(r)

    if not rows:
        return pd.DataFrame()
    return pd.DataFrame(rows).set_index(["experiment", "bucket"]).sort_index()


# =========================
# Samples: FPdiv-by-length + unique-by-length (directly compatible)
# =========================
def compute_samples_by_length(samples_df: pd.DataFrame,
                              cfg: SamplesConfig) -> pd.DataFrame:
    """
    Builds a per-length table from your samples CSV.
    Always computes:
      - n
      - unique_str / unique_rate_str (string-level, cleaned)
    Additionally (if RDKit available + enough parsable SMILES):
      - unique_mol / unique_rate_mol (canonical smiles)
      - fp_div (1 - mean pairwise Tanimoto)
    """
    df = samples_df.copy()

    text_col = cfg.text_col_override or _infer_col(df, cfg.text_cols)
    if text_col is None:
        raise ValueError(f"Cannot infer text/SMILES column. Tried: {cfg.text_cols}")

    valid_col = cfg.valid_col_override or _infer_col(df, cfg.valid_cols)
    length_col = cfg.length_col_override or _infer_col(df, cfg.length_cols)
    token_ids_col = cfg.token_ids_col_override or _infer_col(df, cfg.token_ids_cols)

    # valid-only filter if present
    if valid_col is not None:
        m = _to_bool_series(df[valid_col])
        df = df[m].copy()

    # clean string
    df["_text"] = df[text_col].map(lambda s: _clean_text(s, cfg.strip_after_special_token))

    # length
    if length_col is not None:
        df["_len"] = pd.to_numeric(df[length_col], errors="coerce")
    elif token_ids_col is not None:
        df["_len"] = df[token_ids_col].map(_parse_token_list).map(lambda v: len(v) if isinstance(v, list) else np.nan)
    else:
        # last-resort fallback (avoid if you care about true token lengths)
        df["_len"] = df["_text"].astype(str).str.len()

    df = df[df["_len"].notnull()].copy()
    df["_len"] = df["_len"].astype(int)

    # string-level unique
    rows = []
    rng = np.random.default_rng(0)

    # Try RDKit (optional)
    rdkit_ok = False
    Chem = DataStructs = AllChem = None
    try:
        from rdkit import Chem as _Chem, DataStructs as _DataStructs
        from rdkit.Chem import AllChem as _AllChem
        Chem, DataStructs, AllChem = _Chem, _DataStructs, _AllChem
        rdkit_ok = True
    except Exception:
        rdkit_ok = False

    # Pre-check if this looks like SMILES at all: try parse a small sample
    parse_ratio = 0.0
    if rdkit_ok and len(df) > 0:
        probe = df["_text"].sample(n=min(100, len(df)), random_state=0).tolist()
        ok = 0
        for s in probe:
            if Chem.MolFromSmiles(s) is not None:
                ok += 1
        parse_ratio = ok / len(probe)

    use_rdkit = rdkit_ok and (parse_ratio >= 0.2)  # heuristic: at least some SMILES parse

    for L, g in df.groupby("_len"):
        texts = g["_text"].tolist()
        n = len(texts)
        uniq_str = len(set(texts))
        uniq_rate_str = uniq_str / n if n > 0 else np.nan

        out = {
            "length": int(L),
            "n": int(n),
            "unique_str": int(uniq_str),
            "unique_rate_str": float(uniq_rate_str),
            "unique_mol": np.nan,
            "unique_rate_mol": np.nan,
            "fp_div": np.nan,
        }

        if use_rdkit:
            # subsample per length for fp-div computation
            idx = np.arange(n)
            if n > cfg.max_per_len:
                idx = rng.choice(idx, size=cfg.max_per_len, replace=False)
                g2 = g.iloc[idx]
            else:
                g2 = g

            mols, canon = [], []
            for s in g2["_text"].tolist():
                mol = Chem.MolFromSmiles(s)
                if mol is None:
                    continue
                mols.append(mol)
                canon.append(Chem.MolToSmiles(mol, canonical=True))

            if len(canon) > 0:
                um = len(set(canon))
                out["unique_mol"] = int(um)
                out["unique_rate_mol"] = float(um / len(canon))

            if len(mols) > 1:
                from rdkit.Chem.rdFingerprintGenerator import GetMorganGenerator

                gen = GetMorganGenerator(radius=cfg.morgan_radius, fpSize=cfg.morgan_nbits)
                fps = [gen.GetFingerprint(m) for m in mols]

                sum_sims = 0.0
                pairs = 0
                for i in range(1, len(fps)):
                    sims = DataStructs.BulkTanimotoSimilarity(fps[i], fps[:i])
                    sum_sims += float(np.sum(sims))
                    pairs += i
                mean_sim = sum_sims / pairs if pairs > 0 else np.nan
                out["fp_div"] = float(1.0 - mean_sim) if mean_sim == mean_sim else np.nan

        rows.append(out)

    return pd.DataFrame(rows).sort_values("length").set_index("length")


def plot_samples_metric_by_length(exps: Dict[str, Dict[str, str]],
                                  style: PlotStyle,
                                  cfg: SamplesConfig,
                                  metric: str,
                                  title: str,
                                  ylabel: str) -> None:
    series_map = {}
    for exp_name, payload in exps.items():
        spath = payload.get("samples")
        if not spath:
            continue
        df = load_samples_csv(spath)
        byL = compute_samples_by_length(df, cfg)
        if metric not in byL.columns:
            continue
        series_map[exp_name] = byL[metric]

    if not series_map:
        print(f"No samples csv / metric '{metric}' available; skipping '{title}'.")
        return

    all_lens = sorted(set().union(*[set(s.index.tolist()) for s in series_map.values()]))
    x = np.array(all_lens, dtype=int)

    plt.figure(figsize=style.figsize_by_len, dpi=style.dpi)
    for name, s in series_map.items():
        y = np.array([s.get(L, np.nan) for L in all_lens], dtype=float)
        plt.plot(x, y, marker=style.marker, linewidth=style.linewidth, label=name)

    plt.title(title, fontsize=style.title_fontsize)
    plt.xlabel("Length", fontsize=style.label_fontsize)
    plt.ylabel(ylabel, fontsize=style.label_fontsize)
    plt.grid(True, alpha=style.grid_alpha)
    plt.legend(ncol=min(style.legend_ncol, len(series_map)), frameon=style.legend_frameon)
    plt.tight_layout()
    plt.show()


# =========================
# End-to-end runner (FIXED to match the updated JSON histogram functions)
# =========================
def run_analysis(
    exps: Dict[str, Dict[str, str]],
    style: PlotStyle = PlotStyle(),
    buckets: Buckets = Buckets(),
    keys: JsonKeys = JsonKeys(),          # kept for by-length metrics keys
    samples_cfg: SamplesConfig = SamplesConfig(),
    plot_prefix: bool = True,
    plot_len_hist: bool = True,
    plot_by_len_json: bool = True,
    plot_by_len_samples: bool = True,
) -> Dict[str, pd.DataFrame]:
    tables: Dict[str, pd.DataFrame] = {}

    # ---- main table ----
    main_df = make_main_table(exps, buckets=buckets)
    tables["main_table"] = main_df
    if len(main_df) > 0:
        display(main_df)
        main_df.to_csv("main_table.csv")

    # ---- length histograms from JSON (FIXED) ----
    if plot_len_hist:
        # binned histogram now computed from len_counts(_valid) primarily
        plot_length_histogram_binned(
            exps,
            buckets=buckets,
            style=style,
            valid_only=True,
            title="Length histogram (valid-only, binned)",
        )

        # fine histogram now uses len_counts_valid / score_count_by_len_valid
        plot_length_histogram_fine(
            exps,
            style=style,
            normalize=True,
            valid_only=True,
            title="Length histogram (valid-only, per-length)",
        )

    # ---- score-by-length + diversity-by-length from JSON (unchanged) ----
    if plot_by_len_json:
        plot_metric_by_length_from_json(
            exps,
            style=style,
            key=keys.score_mean_by_len_valid,
            title=f"Score by length (valid-only) [{keys.score_mean_by_len_valid}]",
            ylabel="score mean (valid-only)",
        )
        plot_metric_by_length_from_json(
            exps,
            style=style,
            key=keys.diversity_by_len_valid,
            title=f"Token diversity by length (valid-only) [{keys.diversity_by_len_valid}]",
            ylabel="token diversity (valid-only)",
        )

    # ---- prefix plots + bucket table ----
    if plot_prefix:
        plot_prefix_panels(
            exps,
            buckets=buckets,
            style=style,
            suptitle="Prefix metrics (correct-only)",
        )
        pref_bucket = make_prefix_bucket_table(exps, buckets=buckets)
        tables["prefix_bucket_table"] = pref_bucket
        if len(pref_bucket) > 0:
            display(pref_bucket)
            pref_bucket.to_csv("prefix_bucket_table.csv")

    # ---- samples-derived by-length: fp_div + unique + counts ----
    if plot_by_len_samples:
        bylen_tables = {}
        for exp_name, payload in exps.items():
            spath = payload.get("samples")
            if not spath:
                continue
            sdf = load_samples_csv(spath)
            byL = compute_samples_by_length(sdf, samples_cfg)
            bylen_tables[exp_name] = byL

        if bylen_tables:
            tables["samples_by_length_last"] = list(bylen_tables.values())[-1]
            merged = None
            for name, t in bylen_tables.items():
                tt = t.add_prefix(f"{name}/")
                merged = tt if merged is None else merged.join(tt, how="outer")
            tables["samples_by_length_merged"] = merged
            display(merged)
            merged.to_csv("samples_by_length_merged.csv")

        plot_samples_metric_by_length(
            exps,
            style=style,
            cfg=samples_cfg,
            metric="fp_div",
            title="FP diversity by length (valid-only samples; RDKit if applicable)",
            ylabel="1 - mean Tanimoto",
        )
        plot_samples_metric_by_length(
            exps,
            style=style,
            cfg=samples_cfg,
            metric="unique_rate_str",
            title="Unique (string) rate by length (valid-only samples)",
            ylabel="unique / n",
        )
        plot_samples_metric_by_length(
            exps,
            style=style,
            cfg=samples_cfg,
            metric="n",
            title="Valid samples count by length (from samples CSV)",
            ylabel="count",
        )

    return tables


# ============================================================
# Example usage (unchanged)
# ============================================================
style = PlotStyle(dpi=180, linewidth=2.3, marker="o")
buckets = Buckets(prefix_bins={"short": (1, 3), "mid": (4, 7), "long": (8, 10)})

samples_cfg = SamplesConfig(max_per_len=512)

tables = run_analysis(
    exps,
    style=style,
    buckets=buckets,
    keys=JsonKeys(),
    samples_cfg=samples_cfg,
    plot_prefix=True,
    plot_len_hist=True,
    plot_by_len_json=True,
    plot_by_len_samples=True,
)
# Out:
#                    acc  diversity_valid  diversity  score_mean_valid  \
# experiment
# RapTB_len15   0.999687         2.016814   2.017172          0.713047
# TB_CFG_len15  0.999062         1.824090   1.826965          0.715195
#
#               score_mean  len_mean   len_std  len_p50  len_p90  len_p95  \
# experiment
# RapTB_len15     0.712812  4.772188  2.976719     4.16     9.23     9.75
# TB_CFG_len15    0.714492  3.064531  2.319531     2.17     6.37     7.28
#
#               len_valid_frac[0-2]  len_valid_frac[3-5]  len_valid_frac[6-8]  \
# experiment
# RapTB_len15              0.329165             0.331354             0.186933
# TB_CFG_len15             0.594620             0.268377             0.074132
#
#               len_valid_frac[9-10]  len_valid_frac[11+]  len_frac[0-2]  \
# experiment
# RapTB_len15               0.095030             0.057518       0.329062
# TB_CFG_len15              0.047545             0.015327       0.594063
#
# ...

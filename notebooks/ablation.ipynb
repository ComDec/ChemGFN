# %%
import ast
import pandas as pd
import numpy as np

# %%
baseline = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_5_to_2_mix/train/runs/2025-12-31_09-16-12/validation_samples/samples_val_probes_7300.csv"
baseline_wo_replay = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_5_to_2_mix_no_replay/train/runs/2026-01-02_15-13-15/validation_samples/samples_val_probes_5900.csv"
baseline_wo_absorb = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_10_mix_fix/train/runs/2026-01-12_00-10-28/validation_samples/samples_val_probes_4284.csv"
baseline_subM_full = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_add_len_func/train/runs/2026-01-06_13-25-40/validation_samples/samples_val_probes_6500.csv"
baseline_length = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_len_func_only/train/runs/2026-01-06_13-24-27/validation_samples/samples_val_probes_6800.csv"
baseline_div_only = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_div_only/train/runs/2026-01-04_12-30-00/validation_samples/samples_val_probes_10000.csv"
baseline_rew_only = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_rew_only/train/runs/2026-01-04_12-30-17/validation_samples/samples_val_probes_8600.csv"
# baseline_div_rew_only = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_5_to_2_mix_subM_replay_div_rew_only/train/runs/2026-01-04_12-30-43/validation_samples/samples_val_probes_300.csv"
baseline_detach_pterm = "/data1/xw3763/project/gflow/ChemGFN/logs/train/smiles_RapTB_v2_kmin_5_to_2_mix_wo_detach_term/train/runs/2026-01-04_12-37-52/validation_samples/samples_val_probes_8700.csv"

# %%
all_path = [baseline, baseline_wo_replay, baseline_wo_absorb, baseline_subM_full, baseline_length, baseline_div_only, baseline_rew_only, baseline_detach_pterm]
name = ["baseline", "baseline_wo_replay", "baseline_wo_absorb", "baseline_subM_full", "baseline_length", "baseline_div_only", "baseline_rew_only", "baseline_detach_pterm"]

for idx, path in enumerate(all_path):
    df = pd.read_csv(path)
    ist_base = [ast.literal_eval(token) for token in df["token_ids"].tolist()]
    ist_base_length = [len(token) for token in ist_base]
    print(name[idx])
    print(np.array(ist_base_length).mean())
# Out:
# baseline
# 6.446875
# baseline_wo_replay
# 5.23125
# baseline_wo_absorb
# 5.29625
# baseline_subM_full
# 7.9875
# baseline_length
# 6.56875
# baseline_div_only
# 5.459375
# baseline_rew_only
# 8.121875
# baseline_detach_pterm
# 3.403125
